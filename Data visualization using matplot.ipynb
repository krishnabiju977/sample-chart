# %%
import pandas as pd
import matplotlib.pyplot as plt
s=pd.read_csv(r"C:Documents/Salaries modi.csv")
s
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#LINE CHART
plt.plot(s['salary'])
plt.title('salary information')
plt.xlabel('salary count')
plt.ylabel('salaries in thousand')
plt.show()

# %% [markdown]
# # BAR CHART

# %%
plt.bar(x=s['sex'],height=s['phd'])
plt.show()

# %%
#HISTOGRAM

# %%
plt.hist(s['salary'],bins=20,histtype='bar',color='green')
plt.show()

# %%
#SCATTER PLOT

# %%
plt.scatter(s['salary'],s['service'],marker='*',c='red')
plt.xlabel('salary')
plt.ylabel('service')
plt.show()

# %%
#Using Different Style

# %%
from matplotlib import pyplot as plt
from matplotlib import style

# %%
#style.use('ggplot')
#style.use('fivethirtyeight')
style.use('dark_background')
plt.plot(s['service'],linewidth=3,c='b')
plt.scatter(s['phd'],s['service'],linewidth=1,marker='*',c='y')
plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.grid(True,color='r',linestyle='-',linewidth=3)
plt.show()

# %%
style.use('grayscale')
x=[5,8,10]
y=[12,16,6]
x2=[5,9,11]
y2=[6,15,3]
plt.plot(x,y,'g',label='line one',linewidth=5,linestyle="-")
plt.plot(x2,y2,'c',label='line two',linewidth=5,linestyle="--")
plt.title('Epic Info')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.grid(True,color='y',linestyle='-',linewidth=3)
plt.show()

# %%
plt.plot(s['phd'],'y',label='line one',linewidth=3,linestyle='-')
plt.plot(s['service'],'c',label='line two',linewidth=5,linestyle='-.')
plt.title('Epic Info')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()

# %%
from matplotlib.figure import Figure
fig=plt.figure(figsize=(2,2))
ax=fig.add_axes([1,1,2,2])
plt.scatter(s['phd'],s['service'])
plt.show()

# %%
#creating the axes object with argument as[left,bottam,width,height]
#'hammer','polar','lambert','rectilinear','aitoff','mollweide','str')
ax=plt.axes([1,1,1,1],projection='polar')

# %%
ax=plt.axes([1,1,1,1],projection='lambert')

# %%
ax=plt.axes([1,1,1,1],projection='rectilinear')

# %%
ax=plt.axes([1,1,1,1],projection='hammer')

# %%
from matplotlib.figure import Figure
fig=plt.figure(figsize=(5,4))
style.use('ggplot')
ax=fig.add_axes([1,1,1,1]) #adding axes to the f
ax1=ax.plot([1,2,3,4],[1,2,3,4])
ax2=ax.plot([1,2,3,4],[2,3,4,5])
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3])
y=np.array([5,4,6,7])

plt.subplot(2,3,1)
plt.scatter(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,2)
plt.plot(x,y)#hist(x)
 
plt.subplot(2,3,3)
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt
from matplotlib import style
#plot1
plt.figure(figsize=(5,3))
plt.subplot(1,3,1)
plt.plot(s['salary'])
plt.title("Salary by Profession")

#plot2
plt.figure(figsize=(5,3))
plt.subplot(1,3,2)
plt.scatter(s['service'],s['phd'])
plt.title("Experience by Profession")

#plot3
plt.figure(figsize=(5,3))
plt.subplot(1,3,3)
plt.bar(s['rank'],height=s['rank'])
plt.title("Rank holding")

plt.suptitle("Employee salaries")
plt.show()

# %%
#creates 3d plot
from matplotlib import pyplot as plt
from matplotlib import style
fig=plt.figure()
ax=plt.axes(projection='3d')

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
z=[1,8,27,64,125]
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.bar3d(x,y,z,dx=0.5,dy=0.6,dz=20)#only bars need dx,dy etc we can also scatter 3d like this

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
z=[1,8,27,64,125]
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.scatter3D(x,y,z)
